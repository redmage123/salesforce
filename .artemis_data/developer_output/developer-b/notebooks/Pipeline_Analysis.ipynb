# %% [markdown]
# # Artemis Pipeline Performance Analysis

# %%
from src.data_loader import DataLoader, CSVDataSourcefrom src.data_analyzer import DataAnalyzerfrom src.visualizer import Visualizerdata_source = CSVDataSource('data/pipeline_data.csv')data_loader = DataLoader(data_source)data = data_loader.get_data()analyzer = DataAnalyzer(data)print(analyzer.get_summary_statistics())visualizer = Visualizer(data)visualizer.plot_histogram('column_name')visualizer.plot_scatter('column_x', 'column_y')
