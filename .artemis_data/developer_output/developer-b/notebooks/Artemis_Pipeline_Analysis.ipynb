# %% [markdown]
# # Artemis Pipeline Performance Analysis
# This notebook provides an analysis of the Artemis pipeline performance.

# %%
# Import necessary modules
from src.data_loading import CSVDataLoader
from src.data_analysis import DataAnalyzer
from src.visualization import DataVisualizer

# Load data
data_loader = CSVDataLoader()
data = data_loader.load_data('data/pipeline_data.csv')

# Analyze data
analyzer = DataAnalyzer(data)
analysis_results = analyzer.analyze()

# Visualize data
visualizer = DataVisualizer(data)
fig = visualizer.create_visualization(column='execution_time', plot_type='scatter')
fig.show()
