# %% [markdown]
# # Artemis Pipeline Performance Analysis

# %%
from src.data_loader import DataLoader, CSVDataLoader
from src.data_analyzer import DataAnalyzer
from src.visualization import Visualizer
import pandas as pd

# Load data
loader = DataLoader(CSVDataLoader())
data = loader.load('pipeline_data.csv')

# Analyze data
analyzer = DataAnalyzer(data)
metrics = analyzer.compute_metrics()
print(metrics)

# Visualize data
visualizer = Visualizer(data)
fig = visualizer.generate_interactive_plot('timestamp', 'execution_time')
fig.show()
